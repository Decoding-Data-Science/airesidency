# %% [markdown]
# <a href="https://colab.research.google.com/github/Decoding-Data-Science/airesidency/blob/main/Copy_of_playground_to_python_9thmay.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
pip install openai

# %%
import os
from google.colab import userdata
os.environ["OPENAI_API_KEY"] = userdata.get("openai")

# %%
import os
from openai import OpenAI
# Create client
client = OpenAI()
# Ask a question
question = input("Enter your question: ")
# Call the application
response = client.responses.create(
    prompt={
        "id": "pmpt_69f6045c7b2081948d9105d9ab575ba5002abf8d4ba5b59b",
        "version": "1"
    },
    input=question,
    reasoning={
        "summary": "auto"
    }
)

# Print answer
print("\nAnswer:\n")
print(response.output_text)
# Out:
# Enter your question: what is tuple?
#
# Answer:
#
# Analogy: A tuple in Python is like a small labeled box that holds items you don’t want to change later. It’s useful when you want to group related values together, like a pair of coordinates or a date.
#
# ```python
# # A tuple in Python
# # Tuples store multiple values in one place
# # and they cannot be changed after creation (they are "immutable").
#
# # Create a tuple
# my_tuple = (10, 20, 30)
#
# # Print the whole tuple
# print(my_tuple)  # Output: (10, 20, 30)
#
# # Access the first item using indexing
# print(my_tuple[0])  # Output: 10
#
# # You can loop through a tuple just like a list
# for item in my_tuple:
#     print(item)  # Prints 10, then 20, then 30
# ```
#
# A few beginner-friendly points:
# - A tuple uses **parentheses** `()`
# - You can **read** items from it
# - You cannot **change** items after it is created
#
# If you want, I can also explain the difference between a **tuple** and a **list**.

# %%
pip install gradio

# %%
import os
from openai import OpenAI
import gradio as gr

# Load API key from Colab Secrets
from google.colab import userdata
os.environ["OPENAI_API_KEY"] = userdata.get("openai")

# Create OpenAI client
client = OpenAI()

# Function to ask the app
def ask_app(question):
    try:
        response = client.responses.create(

            prompt={
                #change this id
                "id": "pmpt_69f6045c7b2081948d9105d9ab575ba5002abf8d4ba5b59b",
                "version": "1"
            },
            input=question,
            reasoning={
                "summary": "auto"
            }
        )
        return response.output_text
    except Exception as e:
        return f"Error: {str(e)}"

# Gradio interface
demo = gr.Interface(
    fn=ask_app,
    inputs=gr.Textbox(
        lines=3,
        placeholder="Type your question here...",
        label="Your Question"
    ),
    outputs=gr.Textbox(
        lines=10,
        label="Answer"
    ),
    title="DDS Cohort 10 2nd App Python Bot",
    description="Ask a question and get answers from your saved prompt + vector store."
)

demo.launch(share=True)
# Out:
# Colab notebook detected. To show errors in colab notebook, set debug=True in launch()
# * Running on public URL: https://9fea761e975b8a52fe.gradio.live
#
# This share link expires in 1 week. For free permanent hosting and GPU upgrades, run `gradio deploy` from the terminal in the working directory to deploy to Hugging Face Spaces (https://huggingface.co/spaces)
# <div><iframe src="https://9fea761e975b8a52fe.gradio.live" width="100%" height="500" allow="autoplay; camera; microphone; clipboard-read; clipboard-write;" frameborder="0" allowfullscreen></iframe></div>
