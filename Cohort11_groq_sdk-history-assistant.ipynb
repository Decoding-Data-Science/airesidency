# %% [markdown]
# <a href="https://colab.research.google.com/github/Decoding-Data-Science/airesidency/blob/main/Cohort11_groq_sdk-history-assistant.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
pip install groq
# Out:
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 143.7/143.7 kB 3.7 MB/s eta 0:00:00
# ...

# %%
import os
from google.colab import userdata
groq_api_key = userdata.get("GROQ_API_KEY")

# %%
import os
from groq import Groq

os.environ["GROQ_API_KEY"] = groq_api_key

client = Groq(
    api_key=groq_api_key,
)

chat_completion = client.chat.completions.create(
    messages=[
        {
            "role": "user",
            "content": "Explain the importance of fast language models",
        }
    ],
    model="llama-3.3-70b-versatile",
)

print(chat_completion.choices[0].message.content)
# Out:
# Fast language models are crucial in modern natural language processing (NLP) as they enable efficient and effective text analysis, generation, and understanding. Here are some reasons why fast language models are important:
#
# 1. **Improved User Experience**: Fast language models can process and respond to user input quickly, making applications such as chatbots, virtual assistants, and language translation tools more responsive and user-friendly.
# 2. **Increased Scalability**: Fast language models can handle large volumes of text data, making them essential for big data analytics, text mining, and information retrieval applications.
# 3. **Real-time Applications**: Fast language models are necessary for real-time applications such as sentiment analysis, news monitoring, and social media monitoring, where timely processing and analysis of text data are critical.
# ...

# %%
pip install gradio

# %%
import gradio as gr

def chat_with_groq(message):
    chat_completion = client.chat.completions.create(
        messages=[
            {
        "role": "system",
        "content": "you are python bot , answer only python related question"
      },
            {
                "role": "user",
                "content": message,
            }
        ],
        model="llama-3.3-70b-versatile", # Using the same model as before
    )
    return chat_completion.choices[0].message.content

iface = gr.Interface(fn=chat_with_groq, inputs="textbox", outputs="textbox", title="Groq Chat with Llama 3.3 DDS")
iface.launch()
# Out:
# It looks like you are running Gradio on a hosted Jupyter notebook, which requires `share=True`. Automatically setting `share=True` (you can turn this off by setting `share=False` in `launch()` explicitly).
#
# Colab notebook detected. To show errors in colab notebook, set debug=True in launch()
# * Running on public URL: https://9c5756b0bcf8a44ec6.gradio.live
#
# This share link is temporary and will last for up to 1 week (best effort). For free permanent hosting and GPU upgrades, run `gradio deploy` from the terminal in the working directory to deploy to Hugging Face Spaces (https://huggingface.co/spaces)
# <div><iframe src="https://9c5756b0bcf8a44ec6.gradio.live" width="100%" height="500" allow="autoplay; camera; microphone; clipboard-read; clipboard-write;" frameborder="0" allowfullscreen></iframe></div>

# %%
import gradio as gr

def chat_with_groq(message):
    chat_completion = client.chat.completions.create(
        messages=[
            {
                "role": "system",
                "content": "you are python bot , answer only python related question"
            },
            {
                "role": "user",
                "content": message,
            }
        ],
        model="llama-3.3-70b-versatile",
    )
    return chat_completion.choices[0].message.content


with gr.Blocks(theme=gr.themes.Soft(), css="""
    .gradio-container {
        border: 2px solid #4CAF50;
        border-radius: 10px;
        padding: 20px;
        box-shadow: 5px 5px 15px rgba(0,0,0,0.1);
    }
    .gr-textbox {
        border: 1px solid #ccc;
        border-radius: 5px;
    }
    .gradio-column {
        border: 1px dashed #ddd;
        padding: 10px;
        border-radius: 8px;
        margin: 5px;
    }
""") as demo:
    gr.Markdown("# <center>Groq Chat with Llama 3.3 DDS</center>")
    gr.Markdown("Ask any Python-related questions to the Llama 3.3 bot!")

    with gr.Row():
        with gr.Column(scale=2):
            message_input = gr.Textbox(lines=5, label="Your Message", placeholder="Type your Python question here...")
            with gr.Row():
                submit_btn = gr.Button("Send", variant="primary")
                clear_btn = gr.Button("Clear", variant="secondary")
        with gr.Column(scale=3):
            chatbot_output = gr.Textbox(lines=10, label="Bot's Response", interactive=False)

    submit_btn.click(chat_with_groq, inputs=message_input, outputs=chatbot_output)
    clear_btn.click(lambda: "", outputs=message_input, queue=False)
    clear_btn.click(lambda: "", outputs=chatbot_output, queue=False)

demo.launch()
# Out:
# /tmp/ipykernel_774/3859575539.py:20: UserWarning: The parameters have been moved from the Blocks constructor to the launch() method in Gradio 6.0: theme, css. Please pass these parameters to launch() instead.
#   with gr.Blocks(theme=gr.themes.Soft(), css="""
# It looks like you are running Gradio on a hosted Jupyter notebook, which requires `share=True`. Automatically setting `share=True` (you can turn this off by setting `share=False` in `launch()` explicitly).
#
# Colab notebook detected. To show errors in colab notebook, set debug=True in launch()
# * Running on public URL: https://a96e09166b60cdb18d.gradio.live
#
# This share link is temporary and will last for up to 1 week (best effort). For free permanent hosting and GPU upgrades, run `gradio deploy` from the terminal in the working directory to deploy to Hugging Face Spaces (https://huggingface.co/spaces)
# ...

# %%
import gradio as gr

def chat_with_groq(message):
    chat_completion = client.chat.completions.create(
        messages=[
            {
                "role": "system",
                "content": "you are python bot , answer only python related question"
            },
            {
                "role": "user",
                "content": message,
            }
        ],
        model="llama-3.3-70b-versatile",
    )
    # Return both the message content and the full JSON representation
    return chat_completion.choices[0].message.content, chat_completion.model_dump_json(indent=2)


with gr.Blocks(title="Groq Chat with Llama 3.3 DDS") as demo:
    gr.Markdown("# Groq Chat with Llama 3.3 DDS")
    gr.Markdown("Ask any Python-related questions to the Llama 3.3 bot!")

    message_input = gr.Textbox(lines=5, label="Your Message", placeholder="Type your Python question here...")
    submit_btn = gr.Button("Send")

    with gr.Row():
        chatbot_output = gr.Textbox(lines=10, label="Bot's Response", interactive=False)
        json_output = gr.Textbox(lines=10, label="Full JSON Response", interactive=False)

    submit_btn.click(
        chat_with_groq,
        inputs=message_input,
        outputs=[chatbot_output, json_output]
    )

demo.launch()
# Out:
# It looks like you are running Gradio on a hosted Jupyter notebook, which requires `share=True`. Automatically setting `share=True` (you can turn this off by setting `share=False` in `launch()` explicitly).
#
# Colab notebook detected. To show errors in colab notebook, set debug=True in launch()
# * Running on public URL: https://ba4e400263553aa7e8.gradio.live
#
# This share link is temporary and will last for up to 1 week (best effort). For free permanent hosting and GPU upgrades, run `gradio deploy` from the terminal in the working directory to deploy to Hugging Face Spaces (https://huggingface.co/spaces)
# <div><iframe src="https://ba4e400263553aa7e8.gradio.live" width="100%" height="500" allow="autoplay; camera; microphone; clipboard-read; clipboard-write;" frameborder="0" allowfullscreen></iframe></div>

# %% [markdown]
# # Understanding the 3 Roles in Chat API
#
# ## Think of it like a restaurant
#
# | Role | Who is it? | Example |
# |------|-----------|---------|
# | `system` | Manager's instructions (user never sees this) | "Only answer Python topics" |
# | `user` | The human asking the question | "What is a list?" |
# | `assistant` | The bot's reply (saved for memory) | "A list is a collection..." |
#
# ## Why do we save messages in history?
#
# - **Without history** → bot forgets everything (every message = new conversation)
# - **With history** → bot remembers the full chat (can handle follow-ups)
#
# ## Example flow
#
# ```
# history = [system]                            → bot knows HOW to behave
# history = [system, user1]                     → bot sees 1st question
# history = [system, user1, assistant1]         → bot remembers its answer
# history = [system, user1, assistant1, user2]  → bot sees follow-up WITH context
# ```
#
# ## One line summary
#
# > `system` = rules, `user` = question, `assistant` = answer.
# > Save all three in `history` so the bot remembers the conversation.

# %%
from google.colab import userdata
from groq import Groq

# Get key from Colab secrets
client = Groq(api_key=userdata.get("GROQ_API_KEY"))

# Step 1: System message (manager instruction)
history = [
    {"role": "system", "content": "you are python bot, answer only python related question"}
]

# Step 2: Chat loop
while True:
    user_input = input("You: ")

    if user_input.lower() == "quit":
        print("Bye!")
        break

    # Step 3: Save user message
    history.append({"role": "user", "content": user_input})

    # Step 4: Send to Groq
    response = client.chat.completions.create(
        messages=history,
        model="llama-3.3-70b-versatile",
    )

    reply = response.choices[0].message.content

    # Step 5: Save assistant reply
    history.append({"role": "assistant", "content": reply})

    print(f"Bot: {reply}")
# Out:
# You: hi
# Bot: Hello. How can I assist you with Python today? Do you have a coding question or need help with a specific topic?
# You: what is best place in dubai
# Bot: This conversation is about Python programming. If you have a Python-related question, I'd be happy to help. If you're looking for recommendations about places in Dubai, I can provide a Python script to help you find the best spots.
#
# For example, I can give you a Python script that uses APIs to fetch reviews and ratings of popular places in Dubai. Would you like that?
#
# Here's a sample script:
# ```python
# import requests
#
# def get_place_reviews(api_key, location):
#     url = f"https://maps.googleapis.com/maps/api/place/textsearch/json?query={location}&key={api_key}"
#     response = requests.get(url)
#     data = response.json()
#     return data
#
# # Example usage:
# api_key = "YOUR_API_KEY"
# location = "Dubai"
# reviews = get_place_reviews(api_key, location)
# print(reviews)
# ```
# ...
